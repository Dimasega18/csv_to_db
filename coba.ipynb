# %%
import pandas as pd
from sqlalchemy import create_engine
import glob

# %%
paths = glob.glob('./*.csv')
for y in paths:
    dims = y

print(str(dims))
# Out:
# .\Worlds_Best_50_Hotels.csv

# %%
a = pd.read_csv(f'{dims}',encoding='latin-1',iterator=True,chunksize=10)
next(a).iloc[:,1:]
# Out:
#                  Name      Location  \
# 0     Capella Bangkok       Bangkok
# 1         Passalacqua     Lake Como
# 2  Rosewood Hong Kong     Hong Kong
# 3        Cheval Blanc         Paris
# 4     The Upper House     Hong Kong
# 5   Raffles Singapore     Singapore
# 6          Aman Tokyo         Tokyo
# 7        Soneva Fushi      Maldives
# 8  Atlantis The Royal         Dubai
# 9          Nihi Sumba  Sumba Island
#
#                                             Overview  Total Rooms  \
# 0  A calming riverside oasis in the centre of cac...          101
# 1  A sumptuous Lake Como retreat made for enjoyin...           24
# 2     Masterful minimalism meets marble-lined luxury          413
# 3  Uber-stylish riverside luxury and world-class ...           72
# 4               A temple of Zen high above Hong Kong          117
# 5  History marries hospitality at this original c...          115
# 6    Light-filled, spacious escape in bustling Tokyo           84
# ...

# %%
engine = create_engine(f'postgresql://dimas:ahayde@localhost:5432/cobaaja')
engine.connect()
